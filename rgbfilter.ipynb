# %% [markdown]
# <a href="https://colab.research.google.com/github/lillybethw/DS1002/blob/main/rgbfilter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
import requests

# %%
def imagevariants():
  url = input("Copy the url of your image")
  image = np.asarray(Image.open(requests.get(url, stream=True).raw))

# %%
url = 'https://www.extension.iastate.edu/news/files/eo-news/images/asiaticlilies_adobestock_225777932.jpg'
image = np.asarray(Image.open(requests.get(url, stream=True).raw))

# %%
image
# Out:
# array([[[33, 40,  9],
#         [36, 43, 12],
#         [37, 46, 15],
#         ...,
#         [31, 41,  7],
#         [31, 41,  6],
#         [32, 42,  7]],
#
#        [[33, 40,  9],
#         [35, 42, 11],
#         [36, 45, 14],
#         ...,
#         [32, 42,  7],
#         [33, 43,  8],
#         [33, 43,  6]],
#
#        [[31, 41,  7],
#         [33, 43,  9],
#         [35, 44, 13],
#         ...,
#         [34, 44,  7],
#         [36, 46,  9],
#         [36, 47,  7]],
#
#        ...,
#
#        [[31, 44, 14],
#         [31, 44, 14],
#         [30, 43, 13],
#         ...,
#         [18, 22,  5],
#         [19, 24,  4],
#         [19, 24,  4]],
#
#        [[31, 42, 12],
#         [29, 42, 12],
#         [29, 42, 12],
#         ...,
#         [16, 24,  3],
#         [20, 25,  5],
#         [18, 26,  3]],
#
#        [[32, 41, 12],
#         [31, 42, 12],
#         [30, 41, 11],
#         ...,
#         [17, 27,  3],
#         [19, 27,  4],
#         [18, 28,  3]]], dtype=uint8)

# %%
redimage = image.copy()
redimage[:, :, 1] = 0
redimage[:, :, 2] = 0
redimage = Image.fromarray(redimage)
redimage
# Out:
# <PIL.Image.Image image mode=RGB size=490x337>

# %%
greenimage = image.copy()
greenimage[:, :, 0] = 0
greenimage[:, :, 2]
greenimage
# Out:
# array([[[ 0, 40,  9],
#         [ 0, 43, 12],
#         [ 0, 46, 15],
#         ...,
#         [ 0, 41,  7],
#         [ 0, 41,  6],
#         [ 0, 42,  7]],
#
#        [[ 0, 40,  9],
#         [ 0, 42, 11],
#         [ 0, 45, 14],
#         ...,
#         [ 0, 42,  7],
#         [ 0, 43,  8],
#         [ 0, 43,  6]],
#
#        [[ 0, 41,  7],
#         [ 0, 43,  9],
#         [ 0, 44, 13],
#         ...,
#         [ 0, 44,  7],
#         [ 0, 46,  9],
#         [ 0, 47,  7]],
#
#        ...,
#
#        [[ 0, 44, 14],
#         [ 0, 44, 14],
#         [ 0, 43, 13],
#         ...,
#         [ 0, 22,  5],
#         [ 0, 24,  4],
#         [ 0, 24,  4]],
#
#        [[ 0, 42, 12],
#         [ 0, 42, 12],
#         [ 0, 42, 12],
#         ...,
#         [ 0, 24,  3],
#         [ 0, 25,  5],
#         [ 0, 26,  3]],
#
#        [[ 0, 41, 12],
#         [ 0, 42, 12],
#         [ 0, 41, 11],
#         ...,
#         [ 0, 27,  3],
#         [ 0, 27,  4],
#         [ 0, 28,  3]]], dtype=uint8)
